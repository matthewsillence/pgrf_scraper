# %% [markdown]
# <a href="https://colab.research.google.com/github/matthewsillence/pgrf_scraper/blob/main/pgrf_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests

# %%
import bs4

# %%
for i in range(20):
  url = "https://www.postgraduatefunding.com/search/results?dids=6&ps=30&pg={}".format(i)
  r = requests.get(url)
  soup = bs4.BeautifulSoup(r.text, "html.parser")
  result_list=soup.find_all('ul')
  for info in result_list:
    print(info.getText())
# Out:
# Streaming output truncated to the last 5000 lines.
# Hugh Last and Donald Atkinson Funds Committee Grants
#
# Society for Promotion of Roman Studies
# Varies, but usually UK £200-1,500Closes: January 15th
#
#
#
#
#
#
#
# Hugh Last Fellowship
#
# British School at Rome (BSR)
# Board and lodging at the British School at RomeCloses: Mid-January
#
#
#
#
#
#
#
# Huntington Short-Term Fellowships
#
# Huntington
# US$3,000 per monthCloses: The deadline for applications is November 15th
#
#
#
#
#
#
#
# Hursky Fellowship
#
# Syracuse University
# stipend of $13,040 and a tuition scholarship for 24 credits for the academic year and the following summerCloses: January 1st
#
#
#
#
#
#
#
# IACI Visiting Fellowship in Irish Studies at the National University of Ireland, Galway
#
# Irish-American Cultural Institute (IACI)
# US$4,000Closes: December 31st
#
#
#
#
#
#
#
# Ian Karten Charitable Trust Scholarship (Hebrew and Jewish Studies)
#
# University College London
# UK£1,000 eachCloses: June 1st
# ...
